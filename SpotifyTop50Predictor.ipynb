# %% [markdown]
# <a href="https://colab.research.google.com/github/Sriram-Sudharsan/To-Do_List/blob/main/SpotifyTop50Predictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('/content/top50.csv', encoding='latin-1')

# %%
df
# Out:
#     Unnamed: 0  ... Popularity
# 0            1  ...         79
# 1            2  ...         92
# 2            3  ...         85
# 3            4  ...         86
# 4            5  ...         94
# 5            6  ...         84
# 6            7  ...         92
# 7            8  ...         90
# 8            9  ...         87
# 9           10  ...         95
# 10          11  ...         93
# 11          12  ...         86
# 12          13  ...         88
# 13          14  ...         87
# 14          15  ...         92
# 15          16  ...         82
# 16          17  ...         90
# 17          18  ...         91
# 18          19  ...         88
# 19          20  ...         91
# 20          21  ...         91
# 21          22  ...         91
# 22          23  ...         83
# 23          24  ...         91
# 24          25  ...         89
# 25          26  ...         70
# 26          27  ...         83
# 27          28  ...         89
# 28          29  ...         91
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        50 non-null     int64
#  1   Track.Name        50 non-null     object
#  2   Artist.Name       50 non-null     object
#  3   Genre             50 non-null     object
#  4   Beats.Per.Minute  50 non-null     int64
#  5   Energy            50 non-null     int64
#  6   Danceability      50 non-null     int64
#  7   Loudness..dB..    50 non-null     int64
#  8   Liveness          50 non-null     int64
#  9   Valence.          50 non-null     int64
#  10  Length.           50 non-null     int64
#  11  Acousticness..    50 non-null     int64
#  12  Speechiness.      50 non-null     int64
#  13  Popularity        50 non-null     int64
# dtypes: int64(11), object(3)
# memory usage: 5.6+ KB

# %% [markdown]
# ## Preprocessing

# %%
df = df.drop(['Unnamed: 0', 'Track.Name'], axis=1)

# %%
df
# Out:
#          Artist.Name             Genre  ...  Speechiness.  Popularity
# 0       Shawn Mendes      canadian pop  ...             3          79
# 1           Anuel AA    reggaeton flow  ...             9          92
# 2      Ariana Grande         dance pop  ...            46          85
# 3         Ed Sheeran               pop  ...            19          86
# 4        Post Malone           dfw rap  ...             7          94
# 5         Ed Sheeran               pop  ...             4          84
# 6          Lil Tecca        trap music  ...            29          92
# 7          Sam Smith               pop  ...             9          90
# 8          Lil Nas X       country rap  ...            10          87
# 9      Billie Eilish        electropop  ...            38          95
# 10         Bad Bunny         reggaeton  ...            31          93
# 11          DJ Snake         dance pop  ...             7          86
# ...

# %%
df['Popularity'] = pd.qcut(df['Popularity'], q=2, labels=[0, 1])

# %%
df['Popularity']
# Out:
# 0     0
# 1     1
# 2     0
# 3     0
# 4     1
# 5     0
# 6     1
# 7     1
# 8     0
# 9     1
# 10    1
# 11    0
# 12    0
# 13    0
# 14    1
# 15    0
# 16    1
# 17    1
# 18    0
# 19    1
# 20    1
# 21    1
# 22    0
# 23    1
# 24    1
# 25    0
# 26    0
# 27    1
# 28    1
# 29    1
# 30    0
# 31    1
# 32    1
# 33    1
# 34    1
# 35    1
# 36    1
# 37    0
# 38    0
# 39    0
# 40    0
# 41    1
# 42    0
# 43    0
# 44    0
# 45    0
# 46    0
# 47    0
# 48    0
# 49    0
# Name: Popularity, dtype: category
# Categories (2, int64): [0 < 1]

# %%
def onehot_encode(df, column, prefix):
    df = df.copy()
    dummies = pd.get_dummies(df[column], prefix=prefix)
    df = pd.concat([df, dummies], axis=1)
    df = df.drop(column, axis=1)
    return df
df = onehot_encode(df, 'Genre', 'genre')
df = onehot_encode(df, 'Artist.Name', 'artist')

# %%
y = df.loc[:, 'Popularity']
X = df.drop('Popularity', axis=1)
scaler = StandardScaler()

X = scaler.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.85, random_state=20)

# %% [markdown]
# Modelling

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC

# %%
log_model = LogisticRegression()
knn_model = KNeighborsClassifier()
dec_model = DecisionTreeClassifier()
mlp_model = MLPClassifier()
svm_model = SVC()
log_model.fit(X_train, y_train)
knn_model.fit(X_train, y_train)
dec_model.fit(X_train, y_train)
mlp_model.fit(X_train, y_train)
svm_model.fit(X_train, y_train)
log_acc = log_model.score(X_test, y_test)
knn_acc = knn_model.score(X_test, y_test)
dec_acc = dec_model.score(X_test, y_test)
mlp_acc = mlp_model.score(X_test, y_test)
svm_acc = svm_model.score(X_test, y_test)

# %%
print("Logistic Regression Acc.:", log_acc)
print("K-Nearest-Neighbors Acc.:", knn_acc)
print("Decision Tree Acc.:", dec_acc)
print("Neural Network Acc.:", mlp_acc)
print("Support Vector Machine Acc.:", svm_acc)
# Out:
# Logistic Regression Acc.: 0.625
# K-Nearest-Neighbors Acc.: 0.5
# Decision Tree Acc.: 0.375
# Neural Network Acc.: 0.625
# Support Vector Machine Acc.: 0.75
